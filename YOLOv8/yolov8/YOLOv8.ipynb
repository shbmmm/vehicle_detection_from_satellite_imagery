# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/iitm_2024/v1'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.6/799.6 kB 6.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)  # train the model
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
import os

# Source directory
src_dir = '/content/runs/detect/train'

# Destination directory
dest_dir = '/content/gdrive/My Drive/iitm_2024/yolov8_run1'

# Remove the destination directory if it exists
if os.path.exists(dest_dir):
    shutil.rmtree(dest_dir)

# Copy the directory
shutil.copytree(src_dir, dest_dir)
# Out:
# '/content/gdrive/My Drive/iitm_2024/yolov8_run1'

# %%
# !yolo task=detect mode=predict model='/content/gdrive/My Drive/iitm_2024/train9/weights/best.pt' conf=.1 source='/content/gdrive/My Drive/iitm_2024/data/test_images/sorted_grid'
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/55 /content/gdrive/My Drive/iitm_2024/data/test_images/sorted_grid/row_01_col_01_mumbai_19.1171681_72.8605151_129m.png: 608x640 21 cars, 71.9ms
# image 2/55 /content/gdrive/My Drive/iitm_2024/data/test_images/sorted_grid/row_01_col_02_mumbai_19.1171681_72.8625267_129m.png: 608x640 1 minivan, 111 cars, 7.4ms
# image 3/55 /content/gdrive/My Drive/iitm_2024/data/test_images/sorted_grid/row_01_col_03_mumbai_19.1171681_72.8645384_129m.png: 608x640 1 minivan, 57 cars, 7.3ms
# image 4/55 /content/gdrive/My Drive/iitm_2024/data/test_images/sorted_grid/row_01_col_04_mumbai_19.1171681_72.86655_129m.png: 608x640 1 minivan, 20 cars, 7.3ms
# image 5/55 /content/gdrive/My Drive/iitm_2024/data/test_images/sorted_grid/row_01_col_05_mumbai_19.1171681_72.8685617_129m.png: 608x640 2 minivans, 36 cars, 7.3ms
# ...
